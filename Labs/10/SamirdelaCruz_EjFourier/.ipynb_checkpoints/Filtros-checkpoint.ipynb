# %%
import csv
import numpy as np
from datetime import datetime
import matplotlib.pylab as plt
import pandas as pd
import scipy.signal as signal

# %%
nomDatos=['datos/transacciones2008.txt','datos/transacciones2009.txt','datos/transacciones2010.txt']
datos=[]
for nombre in nomDatos:
    datos.append(pd.read_csv(nombre,sep= ";", header = None))
datos=pd.concat(datos)

# %%
fecha=pd.to_datetime(datos[0],format='%d/%m/%Y %H:%M:%S')+(pd.to_datetime(datos[1],format='%d/%m/%Y %H:%M:%S')-pd.datetime(1899,12,30))

# %%
precio1=datos[2]
precio2=datos[3]
datos=pd.DataFrame()
datos['Fecha']=fecha
datos['Precio']=precio1
datos['Precio']=datos['Precio'].str.replace(',','.').astype(float)
datos=datos.set_index('Fecha')

# %%
print(datos)
# Out:
#                      Precio
# Fecha
# 2008-01-02 08:49:33  499.00
# 2008-01-02 08:49:40  499.00
# 2008-01-02 08:49:58  499.00
# 2008-01-02 08:50:09  499.00
# 2008-01-02 08:50:17  499.40
# 2008-01-02 08:50:20  499.49
# 2008-01-02 08:50:26  499.50
# 2008-01-02 08:50:26  499.00
# 2008-01-02 08:50:34  499.49
# 2008-01-02 08:51:00  499.80
# 2008-01-02 08:54:25  499.50
# 2008-01-02 08:55:12  499.10
# 2008-01-02 08:55:40  499.30
# 2008-01-02 08:55:57  499.10
# 2008-01-02 08:56:10  498.90
# 2008-01-02 08:56:13  498.85
# 2008-01-02 08:57:02  498.75
# 2008-01-02 08:57:06  498.70
# 2008-01-02 08:57:14  498.00
# 2008-01-02 08:58:38  498.40
# 2008-01-02 09:00:14  498.45
# 2008-01-02 09:00:38  498.50
# 2008-01-02 09:01:08  498.40
# 2008-01-02 09:03:08  498.25
# 2008-01-02 09:03:09  498.25
# 2008-01-02 09:03:15  498.25
# 2008-01-02 09:03:15  498.25
# 2008-01-02 09:03:29  498.20
# 2008-01-02 09:03:29  498.25
# 2008-01-02 09:05:11  498.20
# ...                     ...
# 2010-12-30 12:42:10  468.20
# 2010-12-30 12:45:21  468.50
# 2010-12-30 12:46:27  468.00
# 2010-12-30 12:51:41  468.30
# 2010-12-30 12:51:41  468.00
# 2010-12-30 12:51:41  468.20
# 2010-12-30 12:51:45  468.30
# 2010-12-30 12:53:58  468.15
# 2010-12-30 12:54:53  468.00
# 2010-12-30 12:56:06  468.00
# 2010-12-30 12:56:55  467.90
# 2010-12-30 13:04:26  466.50
# 2010-12-30 13:09:24  467.50
# 2010-12-30 13:09:25  467.50
# 2010-12-30 13:10:41  467.50
# 2010-12-30 13:11:10  467.25
# 2010-12-30 13:11:14  467.15
# 2010-12-30 13:27:59  467.45
# 2010-12-30 13:29:24  467.35
# 2010-12-30 13:29:40  467.45
# 2010-12-30 13:29:53  467.50
# 2010-12-30 13:30:11  467.50
# 2010-12-30 13:31:35  467.28
# 2010-12-30 13:31:39  467.30
# 2010-12-30 13:31:40  467.40
# 2010-12-30 13:46:54  468.50
# 2010-12-30 13:52:09  468.60
# 2010-12-30 13:52:10  468.60
# 2010-12-30 13:52:42  468.70
# 2010-12-30 14:01:14  468.80
#
# [1358774 rows x 1 columns]

# %%
#datos.plot(figsize=(20,7))

# %%
datos.to_csv('datos.csv', header=True, index=True)

# %%
datos=pd.read_csv('datos.csv', sep=',', index_col=0)

# %%
datos.plot(figsize=(20,7))

# %%
datos=pd.read_csv('datos.csv', sep=',')
fecha=datos['Fecha'].values
precio=datos['Precio'].values
fecha
# Out:
# array(['2008-01-02 08:49:33', '2008-01-02 08:49:40',
#        '2008-01-02 08:49:58', ..., '2010-12-30 13:52:10',
#        '2010-12-30 13:52:42', '2010-12-30 14:01:14'], dtype=object)

# %%
N  = 2    # Orden del filtro
Wn = 0.01 # Corte de frecuancia
B, A = signal.butter(N, Wn)

# %%
precio_filtrada = signal.filtfilt(B,A, datos['Precio'])

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(211)
plt.plot(fecha,precio, 'b-')
plt.plot(fecha,precio_filtrada, 'r-',linewidth=2)
plt.ylabel("Precio")
plt.legend(['Original','Filtrado'])
plt.title("Precio Transacciones")
ax1.axes.get_xaxis().set_visible(False)
ax1 = fig.add_subplot(212)
plt.plot(fecha,precio-precio_filtrada, 'b-')
plt.ylabel("Precio")
plt.xlabel("Fecha")
plt.legend(['Residuales'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e814e96473d8> in <module>
#      12 plt.xlabel("Fecha")
#      13 plt.legend(['Residuales'])
# ---> 14 plt.show()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172         self.apply_tickdir(tickdir)
#     173
# --> 174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     469                           markersize=self._size,
#     470                           markeredgewidth=self._width, zorder=self._zorder)
# --> 471         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     472         self._set_artist_props(l)
#     473         return l
#
# KeyboardInterrupt:
